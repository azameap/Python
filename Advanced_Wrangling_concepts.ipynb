# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Datasets/imdb_data.csv'
imdb_df = pd.read_csv(path)

# %%
imdb_df.head()
#To get all the columns in the data frame we write a code in python
pd.set_option('display.max_columns', None)

#Before writing this code we were able to see three dots in between the columns section and all the column names
# were not visble to us. with this code we are able to access all the columns

# %%
#Apply Function
# This function is used in pandas data frame to apply a user defined function to a pandas data frame
#for example we want to change the name of one coo lumn to upper case how will we do it?
#efficient method is using a function upper to do it at once
#lets see how we do it here

# %%
#lets define a function
def upper_case(column_name):
  return column_name.upper()

# %%
#after defining a function we make a new column in which we display the upper case charachters
imdb_df['Capital_column'] # lets name the column as capital_column
imdb_df['Capital_column'] = imdb_df['title'] #we want to apply the changes in this title column
imdb_df['Capital_column'] = imdb_df['title'].apply(upper_case)  #here to apply the function to the column we use apply function in pandas

# %%
imdb_df['Capital_column'] = imdb_df['title'].apply(upper_case)

# %%
#now lets display these both title and capital
imdb_df[['title','Capital_column']].head() #then to acess it we need to put double square brackets
# Out:
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                              Capital_column
# 0                    HOT TUB TIME MACHINE 2
# 1  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                  WHIPLASH
# 3                                   KAHAANI
# 4                                MARINE BOY

# %%
import numpy as np

# %%
def revised_profit(revenue, budget):
  if revenue > 0:
    new_profit = revenue - budget
  else:
    new_profit = np.nan

  return new_profit

# %%
imdb_df['new_profit']= imdb_df.apply(lambda x:revised_profit(x['revenue'],x['budget']),axis = 1)
imdb_df[['revenue','budget','new_profit']].head()
# Out:
#     revenue    budget  new_profit
# 0  12314651  14000000    -1685349
# 1  95149435  40000000    55149435
# 2  13092000   3300000     9792000
# 3  16000000   1200000    14800000
# 4   3923970         0     3923970

# %%
list(imdb_df.columns)
# Out:
# ['id',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'Keywords',
#  'cast',
#  'crew',
#  'revenue',
#  'new_profit']

# %%
path = '/content/drive/MyDrive/Datasets/imdb_data.csv'
imdb_df = pd.read_csv(path)
imdb_df['Profit_'] = imdb_df['revenue'] - imdb_df['budget']
imdb_df['profit_margin'] = imdb_df.apply(lambda x: (x['Profit_'] / x['revenue']) * 100, axis=1)
imdb_df['is_profitting'] = imdb_df.apply(lambda x: True if x['profit_margin'] >0 else False, axis = 1)
imdb_df[['profit_margin','is_profitting']].head()
# Out:
#    profit_margin  is_profitting
# 0     -13.685723          False
# 1      57.960864           True
# 2      74.793767           True
# 3      92.500000           True
# 4     100.000000           True

# %%
imdb1 = imdb_df[imdb_df['runtime'] >= 150]
imdb2 = imdb_df[ (imdb_df['runtime'] < 150) & (imdb_df['runtime'] > 100 )]
imdb3 = imdb_df[imdb_df['runtime'] <= 100]

# %%
pd.concat([imdb1,imdb2,imdb3])
# Out:
#         id belongs_to_collection    budget  \
# 47      48                   NaN  44000000
# 51      52                   NaN  12000000
# 76      77                   NaN    500000
# 97      98                   NaN         0
# 107    108                   NaN  72000000
# ...    ...                   ...       ...
# 2987  2988                   NaN         0
# 2988  2989                   NaN         0
# 2989  2990                   NaN         0
# 2990  2991                   NaN         0
# 2998  2999                   NaN  42000000
#
#                                                  genres  \
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51    [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97    [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                 ...
# ...

# %%
imdb1.shape
# Out:
# (135, 23)

# %%
imdb2.shape
# Out:
# (1586, 23)

# %%
sample_df = pd.concat([imdb1,imdb2],axis = 1)

# %%
pd.set_option('display.max_columns', None)

# %%
sample_df.head(1)
# Out:
#       id belongs_to_collection      budget  \
# 47  48.0                   NaN  44000000.0
#
#                                                genres  \
# 47  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
#
#                        homepage    imdb_id original_language  \
# 47  http://thehatefuleight.com/  tt3460252                en
#
#        original_title                                           overview  \
# 47  The Hateful Eight  Bounty hunters seek shelter from a raging bliz...
#
#     popularity                       poster_path  \
# 47   20.328822  /fqe8JxDNO8B8QfOGTdjh6sPCdSC.jpg
#
#                                  production_companies  \
# 47  [{'name': 'Double Feature Films', 'id': 215}, ...
#
#                                  production_countries release_date  runtime  \
# 47  [{'iso_3166_1': 'US', 'name': 'United States o...     12/25/15    167.0
#
#                                      spoken_languages    status  \
# ...

# %%
#only english movies
imdb_df[imdb_df['original_language'] == 'en'].head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity                       poster_path  \
# 0    6.575393  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...      2/20/15     93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
# ...

# %%
released_films = imdb_df.loc[imdb_df['status'] == 'Released',['title']]
released_films.head()
#here we see that in the place where we write the row value for slicing, we have written a condition.
#this can also be done
# Out:
#                                       title
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy

# %%
long_movies = imdb_df.loc[imdb_df['runtime'] >= 100,['imdb_id','original_language']]

english_movies = imdb_df[imdb_df['original_language'] == 'en']

# %%
#inner join
new_table = pd.merge(english_movies[['imdb_id','runtime']],long_movies,how = 'outer', left_on='imdb_id',right_on='imdb_id')

# %%
new_table.head()
# Out:
#      imdb_id  runtime original_language
# 0  tt2637294     93.0               NaN
# 1  tt0368933    113.0                en
# 2  tt2582802    105.0                en
# 3  tt0093743     83.0               NaN
# 4  tt0431021     92.0               NaN

# %%
long_movies.shape
# Out:
# (1820, 2)

# %%
import pandas as pd

# Creating two DataFrames
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index=['a', 'b', 'c'])
df2 = pd.DataFrame({'C': [7, 8, 9], 'D': [10, 11, 12]}, index=['a', 'b', 'c'])

# Joining df1 and df2 based on their indices
result = df1.join(df2)

print(result)
# Out:
#    A  B  C   D
# a  1  4  7  10
# b  2  5  8  11
# c  3  6  9  12

# %%
imdb_df['release_date']
# Out:
# 0        2/20/15
# 1         8/6/04
# 2       10/10/14
# 3         3/9/12
# 4         2/5/09
#           ...
# 2995     4/22/94
# 2996     3/28/13
# 2997    10/11/96
# 2998     1/16/04
# 2999     9/22/11
# Name: release_date, Length: 3000, dtype: object

# %%
imdb_df['release_date'] = pd.to_datetime(imdb_df['release_date'], errors='coerce')
# Out:
# <ipython-input-10-a3252e9cb690>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   imdb_df['release_date'] = pd.to_datetime(imdb_df['release_date'], errors='coerce')

# %% [markdown]
# Want to analyze profits of your favorite movies?💰🤑 Use Pandas and create a new column "profit" to find out the difference between revenue and budget!📊 Then, apply a lambda function to create a "profit_margin" column that calculates the profit margin of each movie as the ratio of its profit to its revenue.😎📈 And don't forget to add a new column "is_profitable" that indicates whether each movie is profitable or not based on its profit!🤔 Finally, print the first 10 rows to see if the new columns have been added correctly

# %%
imdb_df['profit'] = imdb_df['revenue'] - imdb_df['budget']

# %%
imdb_df['profit_margin'] = imdb_df.apply(lambda x: x['profit']/ x['revenue'] * 100, axis = 1)

# %%
imdb_df['is_profitable'] = imdb_df.apply(lambda x: True if x['profit_margin'] > 0 else False, axis = 1)

# %%
profitable = imdb_df[imdb_df['is_profitable']]

# %%
profitable.shape
# Out:
# (2337, 26)

# %% [markdown]
# Are you ready for a movie marathon? 🤩🎥 Let's filter the IMDb dataset for movies that are at least 2 hours long ⏰ and those with a popularity of 50.0 or higher 🌟. Then, let's concatenate these two filtered DataFrames into a new DataFrame 🤝, and sort it by popularity to find the top-rated movies with a runtime of 2 hours or more 🏆🎞️. Can you print the titles and popularity of the top 10 movies in this new DataFrame? 🤔💻

# %%
long_movie = imdb_df['runtime']>= 120

# %%
high_popularity = imdb_df['popularity'] >= 50.0

# %%
long_movie = imdb_df[imdb_df['runtime']>= 120]
high_popularity = imdb_df[imdb_df['popularity'] >= 50.0]
combined_df = pd.concat([long_movie,high_popularity], axis = 0)


sort_df = combined_df.sort_values(by ='popularity', ascending=False)
sorted_df = sort_df.drop_duplicates()

# %%
 print(sorted_df[['title','popularity']].head(10))
# Out:
#                                title  popularity
# 518                     Wonder Woman  294.337037
# 684             Beauty and the Beast  287.253654
# 1695                     Baby Driver  228.032744
# 2326                        Deadpool  187.860492
# 2126  Guardians of the Galaxy Vol. 2  185.330992
# 1309                       Gone Girl  154.801009
# 1715  War for the Planet of the Apes  146.161786
# 1673                 The Dark Knight  123.167259
# 1126                    The Avengers   89.887648
# 2293                      The Circle   88.439243

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
imdb_df['release_date'] = pd.to_datetime(imdb_df['release_date'], errors = 'coerce') #Here it says how to handle errors

# %%
#for example coerce says that if there is an error result should be Not a time
#now we need to extract the release year from thr date
imdb_df['release_year'] = imdb_df['release_date'].dt.year

# %%
imdb_df['release_year']
# Out:
# 0       1970
# 1       1970
# 2       1970
# 3       1970
# 4       1970
#         ...
# 2995    1970
# 2996    1970
# 2997    1970
# 2998    1970
# 2999    1970
# Name: release_year, Length: 3000, dtype: int32

# %%
max_runtime = imdb_df.groupby('release_year')['runtime'].max().reset_index()
max_runtime.rename(columns ={'runtime':'max_runtime'}, inplace = True)

# %%
max_runtime.head()
# Out:
#    release_year  max_runtime
# 0          1970        338.0

# %%
 # Group the data frame by year and item and extract a number of stats from each group
 imdb_df.groupby(['release_year','original_language'], as_index = False).agg({'runtime':"mean",'revenue':'sum','imdb_id':'count'}).sort_values(by='release_year').rename(columns ={'runtime':'avg_runtime','revenue':'total_revenue','imdb_id':'num_movies'})
# Out:
#     release_year original_language  avg_runtime  total_revenue  num_movies
# 0           1970                ar    98.000000        1347747           1
# 20          1970                mr   162.000000        4400000           1
# 21          1970                nb   103.000000        4159678           1
# 22          1970                nl   107.333333       11758002           6
# 23          1970                no    95.500000        2022135           2
# 24          1970                pl    99.000000       30021668           2
# 25          1970                pt   114.666667       65274145           6
# 19          1970                ml   137.000000        2630000           2
# 26          1970                ro   108.750000        1359844           4
# 28          1970                sr    97.000000            198           1
# 29          1970                sv   122.375000       93044087           8
# ...
